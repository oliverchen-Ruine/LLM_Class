# %% [markdown]
# ## 以markdown格式的文本为例，分割文本块和构建faiss索引

# %% [markdown]
# ### 文本分块，每个不超过max_tokens，支持自定义重叠

# %%
import re
import os
import json
import markdown2 
from bs4 import BeautifulSoup
from typing import List, Dict, Any
import requests
import numpy as np

def detect_language(text: str) -> str:
    """自动检测文本主要语言（中文/英文）"""
    chinese_chars = len(re.findall(r'[\u4e00-\u9fff]', text))
    english_chars = len(re.findall(r'[a-zA-Z]', text))
    return 'zh' if chinese_chars > english_chars else 'en'

def split_text_into_chunks(
        text: str,
        max_tokens: int = 500,
        overlap: int = 50,
        language: str = None
) -> List[str]:
    """将长文本切分为多个chunk，保留单词完整性并支持重叠

    Args:
        text: 输入文本
        max_tokens: 每个chunk的最大长度
        overlap: 相邻chunk之间的重叠长度
        language: 可选强制指定语言('zh'/'en')，默认自动检测

    Returns:
        切分后的chunk列表
    """
    # 清理文本并检测语言
    cleaned = re.sub(r'\s+', ' ', text).strip()
    if not cleaned:
        return []

    lang = language or detect_language(cleaned)

    # 中英文不同的分割逻辑
    if lang == 'zh':
        # 中文按句子分割（保留标点）
        sentences = [s for s in re.split(r'(?<=[。！？.!?])', cleaned) if s]
    else:
        # 英文按句子分割（保留单词完整性）
        sentences = [s for s in re.split(r'(?<=[.!?])\s+', cleaned) if s]

    chunks = []
    current_chunk = ""

    for sentence in sentences:
        # 处理超长句子（超过max_tokens）
        if len(sentence) > max_tokens:
            if current_chunk:
                chunks.append(current_chunk)
                current_chunk = ""

            if lang == 'zh':
                # 中文按字符分割（保留重叠）
                chunks.extend([sentence[i:i + max_tokens]
                               for i in range(0, len(sentence), max_tokens - overlap)])
            else:
                # 英文按单词分割（保留单词完整性）
                words = sentence.split()
                current_words = []
                for word in words:
                    if len(' '.join(current_words + [word])) <= max_tokens:
                        current_words.append(word)
                    else:
                        chunks.append(' '.join(current_words))
                        # 保留重叠部分（从尾部取单词）
                        overlap_words = current_words[-overlap:] if overlap < len(current_words) else current_words
                        current_words = overlap_words + [word]
                if current_words:
                    chunks.append(' '.join(current_words))
            continue

        # 正常句子处理
        if len(current_chunk) + len(sentence) > max_tokens:
            if chunks:
                # 计算实际重叠长度（不超过剩余空间）
                effective_overlap = min(
                    overlap,
                    len(current_chunk),
                    max_tokens - len(sentence)
                )
                overlap_part = current_chunk[-effective_overlap:]
                chunks.append(current_chunk)
                current_chunk = overlap_part + sentence
            else:
                # 第一个chunk直接超限
                chunks.append(current_chunk)
                current_chunk = sentence
        else:
            current_chunk += sentence

    if current_chunk:
        chunks.append(current_chunk)

    # 后处理：确保所有chunk都不超限
    final_chunks = []
    for chunk in chunks:
        if len(chunk) > max_tokens:
            if lang == 'zh':
                final_chunks.extend([chunk[i:i + max_tokens]
                                     for i in range(0, len(chunk), max_tokens - overlap)])
            else:
                words = chunk.split()
                current_words = []
                for word in words:
                    if len(' '.join(current_words + [word])) <= max_tokens:
                        current_words.append(word)
                    else:
                        final_chunks.append(' '.join(current_words))
                        current_words = [word]
                if current_words:
                    final_chunks.append(' '.join(current_words))
        else:
            final_chunks.append(chunk)

    return final_chunks

# %% [markdown]
# ### 提取MD文件中的文本内容

# %%
def extract_text_from_md(file_path: str) -> str:
    """提取MD文件中的文本内容"""
    with open(file_path, 'r', encoding='utf-8') as f:
        md_content = f.read()
    # 将MD转换为HTML
    html = markdown2.markdown(md_content)
    # 从HTML中提取纯文本
    soup = BeautifulSoup(html, 'html.parser')
    return soup.get_text()

# %% [markdown]
# ### 将文本块保存为JSON文件

# %%
def save_chunks_to_json(chunks: List[str], output_path: str) -> None:
    """将文本块保存为JSON文件"""
    data = [{"id": i, "text": chunk, "length": len(chunk)} for i, chunk in enumerate(chunks)]
    with open(output_path, 'w', encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=False, indent=2)

# %% [markdown]
# ### 使用本地embedding模型生成文本嵌入向量，支持分批处理

# %%
def generate_embeddings(texts: List[str], model: str = "dengcao/Qwen3-Embedding-8B:Q5_K_M", batch_size: int = 10) -> List[List[float]]:
    """
    使用本地Ollama模型生成文本嵌入向量
    
    参数:
        texts (List[str]): 文本块列表
        model (str): 本地部署的Ollama模型名称
        batch_size (int): 单次批量处理数量
        
    返回:
        List[List[float]]: 文本嵌入向量列表
    """
    all_embeddings = []
    url = "http://localhost:11434/api/embeddings"  # Ollama默认API地址
    
    # 分批处理文本
    total_batches = (len(texts) + batch_size - 1) // batch_size
    for i in range(0, len(texts), batch_size):
        batch = texts[i:i+batch_size]
        batch_num = (i // batch_size) + 1
        print(f"正在处理第 {batch_num}/{total_batches} 批，包含 {len(batch)} 个文本块")
        
        batch_embeddings = []
        for idx, text in enumerate(batch):
            try:
                # 构造Ollama API请求
                payload = {
                    "model": model,
                    "prompt": text,
                    "options": {"temperature": 0.0}  # 确保确定性结果
                }
                
                # 发送请求到本地Ollama服务
                response = requests.post(url, json=payload, timeout=60)
                response.raise_for_status()  # 检查HTTP错误
                
                # 解析响应并获取嵌入向量
                embedding_data = response.json()
                embedding = embedding_data.get("embedding")
                
                if embedding and isinstance(embedding, list):
                    batch_embeddings.append(embedding)
                    print(f"✓ 文本块 {idx+1}/{len(batch)} 完成")
                else:
                    raise ValueError("API响应格式错误，未获取到有效嵌入向量")
                    
            except requests.exceptions.RequestException as e:
                print(f"✗ 文本块 {idx+1} 请求失败: {e}")
                batch_embeddings.append([])  # 添加空向量占位
            except ValueError as ve:
                print(f"✗ 文本块 {idx+1} 解析失败: {ve}")
                batch_embeddings.append([])  # 添加空向量占位
            except Exception as e:
                print(f"✗ 文本块 {idx+1} 未知错误: {e}")
                batch_embeddings.append([])  # 添加空向量占位
                
        # 过滤无效嵌入向量
        valid_embeddings = [emb for emb in batch_embeddings if emb]
        
        # 验证嵌入向量维度一致性
        if valid_embeddings:
            ref_dim = len(valid_embeddings[0])
            for emb in valid_embeddings:
                if len(emb) != ref_dim:
                    print(f"警告! 嵌入向量维度不一致: {len(emb)} vs {ref_dim}")
                    valid_embeddings = []  # 清除非一致批次
                    break
                
        # 添加有效嵌入向量到结果集
        if valid_embeddings:
            all_embeddings.extend(valid_embeddings)
            print(f"第 {batch_num} 批处理完成，获取 {len(valid_embeddings)} 个有效嵌入向量")
        else:
            print(f"✗ 第 {batch_num} 批未获取到有效嵌入向量")
            
        # 添加空向量保持原始顺序
        all_embeddings.extend([[]] * (len(batch_embeddings) - len(valid_embeddings)))
        
    # 最终维度验证
    embedding_dims = {len(emb) for emb in all_embeddings if emb}
    if len(embedding_dims) > 1:
        print(f"警告! 存在不一致的嵌入维度: {embedding_dims}")
    elif embedding_dims:
        print(f"所有嵌入向量维度一致: {next(iter(embedding_dims))}")
    
    return all_embeddings

# %% [markdown]
# ### 将文本块及其向量保存为JSON文件

# %%
def save_embeddings_to_json(chunks: List[Dict[str, Any]], embeddings: List[List[float]], output_path: str) -> None:
    if len(chunks) != len(embeddings):
        raise ValueError("文本块数量与向量数量不匹配")
    
    # 将向量添加到元数据中
    for i, chunk in enumerate(chunks):
        chunk["embedding"] = embeddings[i]
    
    with open(output_path, 'w', encoding='utf-8') as f:
        json.dump(chunks, f, ensure_ascii=False, indent=2)

# %% [markdown]
# ### 创建并保存FAISS索引

# %%
def create_faiss_index(embeddings: List[List[float]], index_path: str) -> None:
    import faiss
    
    # 将Python列表转换为NumPy数组
    vectors = np.array(embeddings, dtype='float32')
    
    # 创建FAISS索引（使用FlatL2进行精确搜索）
    dimension = len(embeddings[0])
    index = faiss.IndexFlatL2(dimension)
    
    # 添加向量到索引
    index.add(vectors)
    
    # 保存索引
    faiss.write_index(index, index_path)
    print(f"FAISS索引已保存到: {index_path}")

# %% [markdown]
# ### 处理单个文件

# %%
def process_single_file(file_path: str, output_dir: str) -> None:
    file_ext = os.path.splitext(file_path)[1].lower()
    file_name = os.path.basename(file_path)
    base_name = os.path.splitext(file_name)[0]
    
    # 确保输出目录存在
    os.makedirs(output_dir, exist_ok=True)
    
    # 提取文本
    if file_ext == '.md':
        text = extract_text_from_md(file_path)
    else:
        print(f"不支持的文件类型: {file_ext}")
        return
    
    # 分割文本
    chunks = split_text_into_chunks(text, max_tokens=400, overlap=50)
    
    # 保存文本块
    output_json_path = os.path.join(output_dir, f"{base_name}_chunks.json")
    save_chunks_to_json(chunks, output_json_path)
    print(f"文件 {file_name} 共分成 {len(chunks)} 段")
    print(f"文本块已保存到 {output_json_path}")
    
    # 生成向量
    print(f"正在使用embedding模型为 {file_name} 生成向量...")
    embeddings = generate_embeddings(chunks)
    
    if embeddings:
        # 转换为字典列表，添加id和length信息
        chunks_with_metadata = [{"id": i, "text": chunk, "length": len(chunk), "source_file": file_name} for i, chunk in enumerate(chunks)]
        
        # 保存带向量的JSON文件
        vector_json_path = os.path.join(output_dir, f"{base_name}_vectors.json")
        save_embeddings_to_json(chunks_with_metadata, embeddings, vector_json_path)
        print(f"向量已保存到 {vector_json_path}")
        
        # 创建并保存FAISS索引
        faiss_index_path = os.path.join(output_dir, f"{base_name}.index")
        create_faiss_index(embeddings, faiss_index_path)
    else:
        print(f"未能为 {file_name} 生成向量")

# %% [markdown]
# ### 批量处理目录中的文件

# %%
def batch_process_files(input_dir: str, output_dir: str, file_extensions: List[str] = ['.pdf', '.md']) -> None:
    # 获取所有符合条件的文件
    files_to_process = []
    for root, _, files in os.walk(input_dir):
        for file in files:
            if any(file.lower().endswith(ext) for ext in file_extensions):
                files_to_process.append(os.path.join(root, file))
    
    if not files_to_process:
        print(f"在 {input_dir} 中没有找到符合条件的文件")
        return
    
    print(f"找到 {len(files_to_process)} 个文件需要处理")
    
    # 逐个处理文件
    for i, file_path in enumerate(files_to_process):
        print(f"\n===== 正在处理文件 {i+1}/{len(files_to_process)}: {os.path.basename(file_path)} =====")
        process_single_file(file_path, output_dir)

# %% [markdown]
# ### 主程序入口

# %%
def main():
    # 配置参数
    input_dir = "./datas/input_files"  # 输入目录，包含PDF和MD文件
    output_dir = "./datas/output"  # 输出目录
    
    # 批量处理文件
    batch_process_files(input_dir, output_dir)

# %% [markdown]
# ### 主程序入口

# %%
if __name__ == "__main__":
    main()
# Out:
# 找到 4 个文件需要处理
#
# ===== 正在处理文件 1/4: 中国文化通史明代卷2.md =====
# 文件 中国文化通史明代卷2.md 共分成 442 段
# 文本块已保存到 ./datas/output/中国文化通史明代卷2_chunks.json
# 正在使用embedding模型为 中国文化通史明代卷2.md 生成向量...
# 正在处理第 1/45 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 1 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 2/45 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 2 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 3/45 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 3 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 4/45 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 4 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 5/45 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 5 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 6/45 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 6 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 7/45 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 7 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 8/45 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 8 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 9/45 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 9 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 10/45 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 10 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 11/45 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 11 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 12/45 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 12 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 13/45 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 13 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 14/45 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 14 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 15/45 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 15 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 16/45 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 16 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 17/45 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 17 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 18/45 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 18 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 19/45 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 19 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 20/45 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 20 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 21/45 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 21 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 22/45 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 22 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 23/45 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 23 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 24/45 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 24 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 25/45 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 25 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 26/45 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 26 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 27/45 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 27 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 28/45 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 28 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 29/45 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 29 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 30/45 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 30 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 31/45 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 31 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 32/45 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 32 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 33/45 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 33 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 34/45 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 34 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 35/45 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 35 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 36/45 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 36 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 37/45 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 37 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 38/45 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 38 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 39/45 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 39 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 40/45 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 40 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 41/45 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 41 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 42/45 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 42 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 43/45 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 43 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 44/45 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 44 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 45/45 批，包含 2 个文本块
# ✓ 文本块 1/2 完成
# ✓ 文本块 2/2 完成
# 第 45 批处理完成，获取 2 个有效嵌入向量
# 所有嵌入向量维度一致: 4096
# 向量已保存到 ./datas/output/中国文化通史明代卷2_vectors.json
# FAISS索引已保存到: ./datas/output/中国文化通史明代卷2.index
#
# ===== 正在处理文件 2/4: 中国文化通史民国卷1.md =====
# 文件 中国文化通史民国卷1.md 共分成 1008 段
# 文本块已保存到 ./datas/output/中国文化通史民国卷1_chunks.json
# 正在使用embedding模型为 中国文化通史民国卷1.md 生成向量...
# 正在处理第 1/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 1 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 2/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 2 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 3/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 3 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 4/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 4 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 5/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 5 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 6/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 6 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 7/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 7 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 8/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 8 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 9/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 9 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 10/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 10 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 11/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 11 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 12/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 12 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 13/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 13 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 14/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 14 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 15/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 15 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 16/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 16 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 17/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 17 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 18/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 18 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 19/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 19 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 20/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 20 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 21/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 21 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 22/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 22 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 23/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 23 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 24/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 24 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 25/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 25 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 26/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 26 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 27/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 27 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 28/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 28 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 29/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 29 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 30/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 30 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 31/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 31 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 32/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 32 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 33/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 33 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 34/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 34 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 35/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 35 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 36/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 36 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 37/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 37 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 38/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 38 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 39/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 39 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 40/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 40 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 41/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 41 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 42/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 42 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 43/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 43 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 44/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 44 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 45/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 45 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 46/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 46 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 47/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 47 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 48/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 48 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 49/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 49 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 50/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 50 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 51/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 51 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 52/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 52 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 53/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 53 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 54/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 54 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 55/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 55 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 56/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 56 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 57/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 57 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 58/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 58 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 59/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 59 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 60/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 60 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 61/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 61 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 62/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 62 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 63/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 63 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 64/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 64 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 65/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 65 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 66/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 66 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 67/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 67 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 68/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 68 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 69/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 69 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 70/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 70 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 71/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 71 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 72/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 72 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 73/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 73 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 74/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 74 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 75/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 75 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 76/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 76 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 77/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 77 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 78/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 78 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 79/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 79 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 80/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 80 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 81/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 81 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 82/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 82 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 83/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 83 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 84/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 84 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 85/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 85 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 86/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 86 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 87/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 87 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 88/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 88 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 89/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 89 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 90/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 90 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 91/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 91 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 92/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 92 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 93/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 93 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 94/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 94 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 95/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 95 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 96/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 96 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 97/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 97 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 98/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 98 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 99/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 99 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 100/101 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 100 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 101/101 批，包含 8 个文本块
# ✓ 文本块 1/8 完成
# ✓ 文本块 2/8 完成
# ✓ 文本块 3/8 完成
# ✓ 文本块 4/8 完成
# ✓ 文本块 5/8 完成
# ✓ 文本块 6/8 完成
# ✓ 文本块 7/8 完成
# ✓ 文本块 8/8 完成
# 第 101 批处理完成，获取 8 个有效嵌入向量
# 所有嵌入向量维度一致: 4096
# 向量已保存到 ./datas/output/中国文化通史民国卷1_vectors.json
# FAISS索引已保存到: ./datas/output/中国文化通史民国卷1.index
#
# ===== 正在处理文件 3/4: 中国文化通史民国卷2.md =====
# 文件 中国文化通史民国卷2.md 共分成 511 段
# 文本块已保存到 ./datas/output/中国文化通史民国卷2_chunks.json
# 正在使用embedding模型为 中国文化通史民国卷2.md 生成向量...
# 正在处理第 1/52 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 1 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 2/52 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 2 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 3/52 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 3 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 4/52 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 4 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 5/52 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 5 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 6/52 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 6 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 7/52 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 7 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 8/52 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 8 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 9/52 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 9 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 10/52 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 10 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 11/52 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 11 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 12/52 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 12 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 13/52 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 13 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 14/52 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 14 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 15/52 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 15 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 16/52 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 16 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 17/52 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 17 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 18/52 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 18 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 19/52 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 19 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 20/52 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 20 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 21/52 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 21 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 22/52 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 22 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 23/52 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 23 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 24/52 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 24 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 25/52 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 25 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 26/52 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 26 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 27/52 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 27 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 28/52 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 28 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 29/52 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 29 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 30/52 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 30 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 31/52 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 31 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 32/52 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 32 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 33/52 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 33 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 34/52 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 34 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 35/52 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 35 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 36/52 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 36 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 37/52 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 37 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 38/52 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 38 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 39/52 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 39 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 40/52 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 40 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 41/52 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 41 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 42/52 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 42 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 43/52 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 43 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 44/52 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 44 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 45/52 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 45 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 46/52 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 46 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 47/52 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 47 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 48/52 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 48 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 49/52 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 49 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 50/52 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 50 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 51/52 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 51 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 52/52 批，包含 1 个文本块
# ✓ 文本块 1/1 完成
# 第 52 批处理完成，获取 1 个有效嵌入向量
# 所有嵌入向量维度一致: 4096
# 向量已保存到 ./datas/output/中国文化通史民国卷2_vectors.json
# FAISS索引已保存到: ./datas/output/中国文化通史民国卷2.index
#
# ===== 正在处理文件 4/4: 中国文化通史明代卷1.md =====
# 文件 中国文化通史明代卷1.md 共分成 930 段
# 文本块已保存到 ./datas/output/中国文化通史明代卷1_chunks.json
# 正在使用embedding模型为 中国文化通史明代卷1.md 生成向量...
# 正在处理第 1/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 1 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 2/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 2 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 3/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 3 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 4/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 4 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 5/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 5 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 6/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 6 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 7/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 7 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 8/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 8 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 9/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 9 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 10/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 10 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 11/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 11 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 12/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 12 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 13/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 13 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 14/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 14 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 15/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 15 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 16/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 16 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 17/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 17 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 18/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 18 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 19/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 19 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 20/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 20 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 21/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 21 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 22/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 22 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 23/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 23 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 24/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 24 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 25/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 25 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 26/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 26 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 27/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 27 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 28/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 28 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 29/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 29 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 30/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 30 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 31/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 31 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 32/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 32 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 33/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 33 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 34/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 34 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 35/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 35 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 36/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 36 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 37/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 37 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 38/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 38 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 39/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 39 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 40/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 40 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 41/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 41 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 42/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 42 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 43/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 43 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 44/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 44 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 45/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 45 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 46/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 46 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 47/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 47 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 48/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 48 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 49/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 49 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 50/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 50 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 51/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 51 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 52/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 52 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 53/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 53 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 54/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 54 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 55/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 55 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 56/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 56 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 57/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 57 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 58/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 58 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 59/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 59 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 60/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 60 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 61/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 61 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 62/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 62 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 63/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 63 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 64/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 64 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 65/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 65 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 66/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 66 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 67/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 67 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 68/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 68 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 69/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 69 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 70/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 70 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 71/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 71 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 72/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 72 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 73/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 73 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 74/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 74 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 75/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 75 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 76/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 76 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 77/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 77 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 78/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 78 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 79/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 79 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 80/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 80 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 81/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 81 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 82/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 82 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 83/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 83 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 84/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 84 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 85/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 85 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 86/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 86 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 87/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 87 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 88/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 88 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 89/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 89 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 90/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 90 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 91/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 91 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 92/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 92 批处理完成，获取 10 个有效嵌入向量
# 正在处理第 93/93 批，包含 10 个文本块
# ✓ 文本块 1/10 完成
# ✓ 文本块 2/10 完成
# ✓ 文本块 3/10 完成
# ✓ 文本块 4/10 完成
# ✓ 文本块 5/10 完成
# ✓ 文本块 6/10 完成
# ✓ 文本块 7/10 完成
# ✓ 文本块 8/10 完成
# ✓ 文本块 9/10 完成
# ✓ 文本块 10/10 完成
# 第 93 批处理完成，获取 10 个有效嵌入向量
# 所有嵌入向量维度一致: 4096
# 向量已保存到 ./datas/output/中国文化通史明代卷1_vectors.json
# FAISS索引已保存到: ./datas/output/中国文化通史明代卷1.index
